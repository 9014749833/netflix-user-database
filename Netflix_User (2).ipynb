# %%
import pandas as pd
import numpy as np
df=pd.read_csv("netflix_users.csv")
df.head()
# Out:
#    User_ID            Name   Age Country Subscription_Type  Watch_Time_Hours  \
# 0        1  James Martinez  18.0  France           Premium             80.26
# 1        2     John Miller  23.0     USA           Premium            321.75
# 2        3      Emma Davis  60.0      UK             Basic             35.89
# 3        4     Emma Miller  44.0     USA           Premium            261.56
# 4        5      Jane Smith  68.0     USA          Standard            909.30
#
#   Favorite_Genre
# 0          Drama
# 1         Sci-Fi
# 2         Comedy
# 3    Documentary
# 4          Drama

# %%
df.tail()
# Out:
#        User_ID              Name   Age    Country Subscription_Type  \
# 24995    24996      David Miller  18.0  Australia           Premium
# 24996    24997       Jane Miller  17.0        USA           Premium
# 24997    24998      Sarah Miller  14.0        USA           Premium
# 24998    24999  Michael Williams  71.0        USA             Basic
# 24999    25000       James Jones  19.0    Germany           Premium
#
#        Watch_Time_Hours Favorite_Genre
# 24995            183.88         Horror
# 24996            112.37          Drama
# 24997            351.80         Action
# 24998            655.89         Action
# 24999            207.06    Documentary

# %%
print(df.shape)
# Out:
# (25000, 7)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25000 entries, 0 to 24999
# Data columns (total 7 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   User_ID            25000 non-null  int64
#  1   Name               24983 non-null  object
#  2   Age                24992 non-null  float64
#  3   Country            25000 non-null  object
#  4   Subscription_Type  24980 non-null  object
#  5   Watch_Time_Hours   24976 non-null  float64
#  6   Favorite_Genre     25000 non-null  object
# dtypes: float64(2), int64(1), object(4)
# memory usage: 1.3+ MB

# %%
df.describe()
# Out:
#             User_ID           Age  Watch_Time_Hours
# count  25000.000000  24992.000000      24976.000000
# mean   12500.500000     46.484475        500.389758
# std     7217.022701     19.594960        286.406200
# min        1.000000     13.000000          0.000000
# 25%     6250.750000     29.000000        256.467500
# 50%    12500.500000     46.000000        501.380000
# 75%    18750.250000     63.000000        745.707500
# max    25000.000000     80.000000        999.990000

# %%
df1=df.copy(deep=True)

# %% [markdown]
# Finding Null Values

# %%
df.isna().sum()
# Out:
# User_ID               0
# Name                 17
# Age                   8
# Country               0
# Subscription_Type    20
# Watch_Time_Hours     24
# Favorite_Genre        0
# dtype: int64

# %% [markdown]
# Eliminating Null Values

# %%
med=df1["Age"].median()
df1["Age"]=df1["Age"].fillna(med)
df1.isna().sum()
# Out:
# User_ID               0
# Name                 17
# Age                   0
# Country               0
# Subscription_Type    20
# Watch_Time_Hours     24
# Favorite_Genre        0
# dtype: int64

# %%
me=df1["Watch_Time_Hours"].mean()
df1["Watch_Time_Hours"]=df1["Watch_Time_Hours"].fillna(me)
df1.isna().sum()
# Out:
# User_ID               0
# Name                 17
# Age                   0
# Country               0
# Subscription_Type    20
# Watch_Time_Hours      0
# Favorite_Genre        0
# dtype: int64

# %%
df1["Subscription_Type"].fillna("Basic",inplace=True)
df1.isna().sum()
# Out:
# C:\Users\nomit\AppData\Local\Temp\ipykernel_18384\2971476075.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df1["Subscription_Type"].fillna("Basic",inplace=True)
# User_ID               0
# Name                 17
# Age                   0
# Country               0
# Subscription_Type     0
# Watch_Time_Hours      0
# Favorite_Genre        0
# dtype: int64

# %%
df1.dropna(inplace=True)
df1.isna().sum()
# Out:
# User_ID              0
# Name                 0
# Age                  0
# Country              0
# Subscription_Type    0
# Watch_Time_Hours     0
# Favorite_Genre       0
# dtype: int64

# %%
df1["Subscription_Type"].value_counts()
# Out:
# Subscription_Type
# Premium     8394
# Basic       8355
# Standard    8234
# Name: count, dtype: int64

# %%
df1["Favorite_Genre"].value_counts()
# Out:
# Favorite_Genre
# Horror         3652
# Documentary    3632
# Action         3588
# Romance        3570
# Comedy         3560
# Drama          3529
# Sci-Fi         3452
# Name: count, dtype: int64

# %%
df1["Country"].value_counts()
# Out:
# Country
# UK           2588
# Germany      2544
# India        2505
# USA          2503
# Brazil       2502
# Mexico       2491
# Canada       2490
# France       2471
# Japan        2453
# Australia    2436
# Name: count, dtype: int64

# %% [markdown]
# Categorical to Numerical

# %%
mapping={"Basic":100,"Standard":200,"Premium":300}
df1["Subscription_Type"]=df1["Subscription_Type"].map(mapping)
df1.head()
# Out:
#    User_ID            Name   Age Country  Subscription_Type  Watch_Time_Hours  \
# 0        1  James Martinez  18.0  France                300             80.26
# 1        2     John Miller  23.0     USA                300            321.75
# 2        3      Emma Davis  60.0      UK                100             35.89
# 3        4     Emma Miller  44.0     USA                300            261.56
# 4        5      Jane Smith  68.0     USA                200            909.30
#
#   Favorite_Genre
# 0          Drama
# 1         Sci-Fi
# 2         Comedy
# 3    Documentary
# 4          Drama

# %%
from sklearn.preprocessing import LabelEncoder
le=LabelEncoder()
cols=["Country","Favorite_Genre"]
for i in cols:
    df1[i]=le.fit_transform(df1[i])
df1.head()
# Out:
#    User_ID            Name   Age  Country  Subscription_Type  \
# 0        1  James Martinez  18.0        3                300
# 1        2     John Miller  23.0        9                300
# 2        3      Emma Davis  60.0        8                100
# 3        4     Emma Miller  44.0        9                300
# 4        5      Jane Smith  68.0        9                200
#
#    Watch_Time_Hours  Favorite_Genre
# 0             80.26               3
# 1            321.75               6
# 2             35.89               1
# 3            261.56               2
# 4            909.30               3

# %% [markdown]
# Scaling

# %%
x=df1[["Age","Country","Watch_Time_Hours","Subscription_Type"]]
y=df1.Favorite_Genre

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=1)

# %% [markdown]
# K Nearest Neighbour Algorithm

# %%
from sklearn.neighbors import KNeighborsClassifier
knn=KNeighborsClassifier(n_neighbors=3,metric="euclidean")
knn.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(metric='euclidean', n_neighbors=3)

# %%
ypred=knn.predict(x_test)
from sklearn.metrics import accuracy_score
print(accuracy_score(y_test,ypred))
# Out:
# 0.14248549129477686

# %% [markdown]
# Decision Tree Algorithm

# %%
from sklearn.tree import DecisionTreeClassifier
dtc=DecisionTreeClassifier()
dtc.fit(x,y)
# Out:
# DecisionTreeClassifier()

# %%
ypred=dtc.predict(x)
from sklearn.metrics import confusion_matrix
confusion_matrix(y,ypred)
# Out:
# array([[3588,    0,    0,    0,    0,    0,    0],
#        [   0, 3560,    0,    0,    0,    0,    0],
#        [   0,    0, 3632,    0,    0,    0,    0],
#        [   0,    0,    0, 3529,    0,    0,    0],
#        [   0,    0,    0,    0, 3652,    0,    0],
#        [   0,    0,    0,    0,    1, 3569,    0],
#        [   0,    0,    0,    0,    0,    0, 3452]], dtype=int64)

# %%
from sklearn.tree import plot_tree
plot_tree(dtc,feature_names=["Age","Country","Watch_Time_Hours","Subscription_Type"],class_names=["Horror","Documentary","Action","Romance","Comedy","Drama","Sci-Fi"])
# Out:
# [Text(0.600067336553765, 0.990909090909091, 'Age <= 67.5\ngini = 0.857\nsamples = 24983\nvalue = [3588.0, 3560.0, 3632.0, 3529.0, 3652.0, 3570.0, 3452.0]\nclass = Comedy'),
#  Text(0.3043820066555807, 0.9727272727272728, 'Subscription_Type <= 150.0\ngini = 0.857\nsamples = 20266\nvalue = [2859.0, 2878.0, 2916.0, 2850.0, 3012.0, 2945.0, 2806.0]\nclass = Comedy'),
#  Text(0.45222467160467283, 0.9818181818181819, 'True  '),
#  Text(0.1213128776168396, 0.9545454545454546, 'Watch_Time_Hours <= 474.495\ngini = 0.857\nsamples = 6758\nvalue = [978.0, 970.0, 961.0, 966.0, 988.0, 1035.0, 860.0]\nclass = Drama'),
#  Text(0.08012726696634212, 0.9363636363636364, 'Watch_Time_Hours <= 471.855\ngini = 0.857\nsamples = 3175\nvalue = [501.0, 445.0, 442.0, 466.0, 479.0, 438.0, 404.0]\nclass = Horror'),
#  Text(0.04829608663587156, 0.9181818181818182, 'Watch_Time_Hours <= 7.36\ngini = 0.857\nsamples = 3157\nvalue = [495.0, 445.0, 439.0, 459.0, 479.0, 438.0, 402.0]\nclass = Horror'),
#  Text(0.0010527992388651487, 0.9, 'Country <= 3.5\ngini = 0.81\nsamples = 47\nvalue = [4.0, 14.0, 6.0, 4.0, 5.0, 11.0, 3.0]\nclass = Documentary'),
#  Text(0.00028821880303532587, 0.8818181818181818, 'Country <= 0.5\ngini = 0.694\nsamples = 12\nvalue = [1, 1, 1, 4, 0, 5, 0]\nclass = Drama'),
#  Text(0.00012809724579347816, 0.8636363636363636, 'Age <= 36.0\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0, 0]\nclass = Romance'),
#  Text(6.404862289673908e-05, 0.8454545454545455, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0, 0]\nclass = Romance'),
#  Text(0.00019214586869021724, 0.8454545454545455, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.0004483403602771736, 0.8636363636363636, 'Watch_Time_Hours <= 4.915\ngini = 0.617\nsamples = 9\nvalue = [1, 1, 0, 2, 0, 5, 0]\nclass = Drama'),
#  Text(0.0003202431144836954, 0.8454545454545455, 'Watch_Time_Hours <= 1.785\ngini = 0.32\nsamples = 5\nvalue = [0, 1, 0, 0, 0, 4, 0]\nclass = Drama'),
#  Text(0.0002561944915869563, 0.8272727272727273, 'Watch_Time_Hours <= 0.6\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 0, 1, 0]\nclass = Documentary'),
#  Text(0.00019214586869021724, 0.8090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.0003202431144836954, 0.8090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.0003842917373804345, 0.8272727272727273, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 3, 0]\nclass = Drama'),
#  Text(0.0005764376060706517, 0.8454545454545455, 'Country <= 1.5\ngini = 0.625\nsamples = 4\nvalue = [1, 0, 0, 2, 0, 1, 0]\nclass = Romance'),
#  Text(0.0005123889831739126, 0.8272727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.0006404862289673908, 0.8272727272727273, 'Watch_Time_Hours <= 6.03\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 0, 2, 0, 0, 0]\nclass = Romance'),
#  Text(0.0005764376060706517, 0.8090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.00070453485186413, 0.8090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0, 0]\nclass = Romance'),
#  Text(0.0018173796746949714, 0.8818181818181818, 'Watch_Time_Hours <= 5.725\ngini = 0.777\nsamples = 35\nvalue = [3, 13, 5, 0, 5, 6, 3]\nclass = Documentary'),
#  Text(0.001457106170900814, 0.8636363636363636, 'Country <= 7.5\ngini = 0.812\nsamples = 27\nvalue = [3, 7, 3, 0, 5, 6, 3]\nclass = Documentary'),
#  Text(0.0010247779663478253, 0.8454545454545455, 'Watch_Time_Hours <= 1.685\ngini = 0.722\nsamples = 13\nvalue = [1, 2, 2, 0, 1, 6, 1]\nclass = Drama'),
#  Text(0.0008966807205543472, 0.8272727272727273, 'Watch_Time_Hours <= 0.52\ngini = 0.75\nsamples = 4\nvalue = [0, 1, 1, 0, 1, 0, 1]\nclass = Documentary'),
#  Text(0.000832632097657608, 0.8090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Comedy'),
#  Text(0.0009607293434510863, 0.8090909090909091, 'Country <= 4.5\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 1, 0, 0, 0, 1]\nclass = Documentary'),
#  Text(0.0008966807205543472, 0.7909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.0010247779663478253, 0.7909090909090909, 'Age <= 33.5\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 0, 0, 1]\nclass = Documentary'),
#  Text(0.0009607293434510863, 0.7727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.0010888265892445644, 0.7727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.0011528752121413035, 0.8272727272727273, 'Country <= 4.5\ngini = 0.519\nsamples = 9\nvalue = [1, 1, 1, 0, 0, 6, 0]\nclass = Drama'),
#  Text(0.0010888265892445644, 0.8090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.0012169238350380426, 0.8090909090909091, 'Watch_Time_Hours <= 4.275\ngini = 0.406\nsamples = 8\nvalue = [1, 0, 1, 0, 0, 6, 0]\nclass = Drama'),
#  Text(0.0011528752121413035, 0.7909090909090909, 'gini = 0.0\nsamples = 5\nvalue = [0, 0, 0, 0, 0, 5, 0]\nclass = Drama'),
#  Text(0.0012809724579347817, 0.7909090909090909, 'Age <= 22.5\ngini = 0.667\nsamples = 3\nvalue = [1, 0, 1, 0, 0, 1, 0]\nclass = Horror'),
#  Text(0.0012169238350380426, 0.7727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.0013450210808315208, 0.7727272727272727, 'Watch_Time_Hours <= 5.15\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 1, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.0012809724579347817, 0.7545454545454545, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.00140906970372826, 0.7545454545454545, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.001889434375453803, 0.8454545454545455, 'Age <= 48.5\ngini = 0.745\nsamples = 14\nvalue = [2, 5, 1, 0, 4, 0, 2]\nclass = Documentary'),
#  Text(0.0017293128182119552, 0.8272727272727273, 'Watch_Time_Hours <= 3.69\ngini = 0.694\nsamples = 11\nvalue = [0, 4, 1, 0, 4, 0, 2]\nclass = Documentary'),
#  Text(0.001601215572418477, 0.8090909090909091, 'Watch_Time_Hours <= 3.075\ngini = 0.694\nsamples = 7\nvalue = [0, 3, 1, 0, 1, 0, 2]\nclass = Documentary'),
#  Text(0.001537166949521738, 0.7909090909090909, 'Age <= 29.5\ngini = 0.56\nsamples = 5\nvalue = [0, 3, 1, 0, 1, 0, 0]\nclass = Documentary'),
#  Text(0.0014731183266249988, 0.7727272727272727, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.001601215572418477, 0.7727272727272727, 'Watch_Time_Hours <= 1.645\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0, 0]\nclass = Action'),
#  Text(0.001537166949521738, 0.7545454545454545, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Comedy'),
#  Text(0.001665264195315216, 0.7545454545454545, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.001665264195315216, 0.7909090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]\nclass = Sci-Fi'),
#  Text(0.0018574100640054334, 0.8090909090909091, 'Age <= 34.0\ngini = 0.375\nsamples = 4\nvalue = [0, 1, 0, 0, 3, 0, 0]\nclass = Comedy'),
#  Text(0.0017933614411086943, 0.7909090909090909, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 3, 0, 0]\nclass = Comedy'),
#  Text(0.0019214586869021725, 0.7909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.0020495559326956505, 0.8272727272727273, 'Age <= 57.0\ngini = 0.444\nsamples = 3\nvalue = [2, 1, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.0019855073097989114, 0.8090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.0021136045555923896, 0.8090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.0021776531784891287, 0.8636363636363636, 'Country <= 5.5\ngini = 0.375\nsamples = 8\nvalue = [0, 6, 2, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.0021136045555923896, 0.8454545454545455, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.002241701801385868, 0.8454545454545455, 'Age <= 41.0\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.0021776531784891287, 0.8272727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.002305750424282607, 0.8272727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.09553937403287796, 0.9, 'Watch_Time_Hours <= 470.73\ngini = 0.857\nsamples = 3110\nvalue = [491.0, 431.0, 433.0, 455.0, 474.0, 427.0, 399.0]\nclass = Horror'),
#  Text(0.07972876268646227, 0.8818181818181818, 'Watch_Time_Hours <= 470.235\ngini = 0.857\nsamples = 3098\nvalue = [490.0, 426.0, 429.0, 455.0, 474.0, 425.0, 399.0]\nclass = Horror'),
#  Text(0.04829968586232108, 0.8636363636363636, 'Age <= 23.5\ngini = 0.856\nsamples = 3092\nvalue = [490.0, 426.0, 429.0, 452.0, 474.0, 425.0, 396.0]\nclass = Horror'),
#  Text(0.014845818473790089, 0.8454545454545455, 'Age <= 22.5\ngini = 0.853\nsamples = 632\nvalue = [127.0, 88.0, 84.0, 90.0, 84.0, 75.0, 84.0]\nclass = Horror'),
#  Text(0.006707688545112083, 0.8272727272727273, 'Country <= 0.5\ngini = 0.854\nsamples = 572\nvalue = [107.0, 79.0, 80.0, 82.0, 81.0, 65.0, 78.0]\nclass = Horror'),
#  Text(0.002433847670076085, 0.8090909090909091, 'Watch_Time_Hours <= 129.55\ngini = 0.822\nsamples = 55\nvalue = [8.0, 3.0, 11.0, 7.0, 11.0, 2.0, 13.0]\nclass = Sci-Fi'),
#  Text(0.00208158024414402, 0.7909090909090909, 'Age <= 18.5\ngini = 0.75\nsamples = 12\nvalue = [2, 0, 5, 1, 1, 1, 2]\nclass = Action'),
#  Text(0.0019214586869021725, 0.7727272727272727, 'Watch_Time_Hours <= 88.88\ngini = 0.735\nsamples = 7\nvalue = [2, 0, 2, 0, 1, 0, 2]\nclass = Horror'),
#  Text(0.0017933614411086943, 0.7545454545454545, 'Age <= 17.0\ngini = 0.64\nsamples = 5\nvalue = [1, 0, 2, 0, 0, 0, 2]\nclass = Action'),
#  Text(0.0017293128182119552, 0.7363636363636363, 'Watch_Time_Hours <= 17.545\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 0, 0, 0, 2]\nclass = Action'),
#  Text(0.001665264195315216, 0.7181818181818181, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.0017933614411086943, 0.7181818181818181, 'Watch_Time_Hours <= 51.56\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 0, 0, 0, 1]\nclass = Action'),
#  Text(0.0017293128182119552, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.0018574100640054334, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.0018574100640054334, 0.7363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.0020495559326956505, 0.7545454545454545, 'Age <= 16.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 0, 1, 0, 0]\nclass = Horror'),
#  Text(0.0019855073097989114, 0.7363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.0021136045555923896, 0.7363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Comedy'),
#  Text(0.002241701801385868, 0.7727272727272727, 'Age <= 21.0\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 3, 1, 0, 1, 0]\nclass = Action'),
#  Text(0.0021776531784891287, 0.7545454545454545, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.002305750424282607, 0.7545454545454545, 'Watch_Time_Hours <= 32.34\ngini = 0.667\nsamples = 3\nvalue = [0, 0, 1, 1, 0, 1, 0]\nclass = Action'),
#  Text(0.002241701801385868, 0.7363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.002369799047179346, 0.7363636363636363, 'Watch_Time_Hours <= 81.8\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 0, 1, 0]\nclass = Action'),
#  Text(0.002305750424282607, 0.7181818181818181, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.002433847670076085, 0.7181818181818181, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.0027861150960081502, 0.7909090909090909, 'Watch_Time_Hours <= 135.945\ngini = 0.817\nsamples = 43\nvalue = [6, 3, 6, 6, 10, 1, 11]\nclass = Sci-Fi'),
#  Text(0.002722066473111411, 0.7727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.0028501637189048894, 0.7727272727272727, 'Watch_Time_Hours <= 197.83\ngini = 0.811\nsamples = 42\nvalue = [6, 2, 6, 6, 10, 1, 11]\nclass = Sci-Fi'),
#  Text(0.0026900421616630416, 0.7545454545454545, 'Watch_Time_Hours <= 187.405\ngini = 0.48\nsamples = 5\nvalue = [0, 0, 0, 0, 3, 0, 2]\nclass = Comedy'),
#  Text(0.0026259935387663025, 0.7363636363636363, 'Age <= 21.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 0, 1, 0, 2]\nclass = Sci-Fi'),
#  Text(0.0025619449158695634, 0.7181818181818181, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]\nclass = Sci-Fi'),
#  Text(0.0026900421616630416, 0.7181818181818181, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Comedy'),
#  Text(0.0027540907845597807, 0.7363636363636363, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0, 0]\nclass = Comedy'),
#  Text(0.0030102852761467367, 0.7545454545454545, 'Watch_Time_Hours <= 449.25\ngini = 0.822\nsamples = 37\nvalue = [6, 2, 6, 6, 7, 1, 9]\nclass = Sci-Fi'),
#  Text(0.0028821880303532585, 0.7363636363636363, 'Watch_Time_Hours <= 202.135\ngini = 0.813\nsamples = 35\nvalue = [5, 1, 6, 6, 7, 1, 9]\nclass = Sci-Fi'),
#  Text(0.00281813940745652, 0.7181818181818181, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.0029462366532499976, 0.7181818181818181, 'Watch_Time_Hours <= 207.685\ngini = 0.811\nsamples = 34\nvalue = [5, 1, 5, 6, 7, 1, 9]\nclass = Sci-Fi'),
#  Text(0.0028821880303532585, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.0030102852761467367, 0.7, 'Watch_Time_Hours <= 431.125\ngini = 0.808\nsamples = 33\nvalue = [4, 1, 5, 6, 7, 1, 9]\nclass = Sci-Fi'),
#  Text(0.0029462366532499976, 0.6818181818181818, 'Watch_Time_Hours <= 404.87\ngini = 0.809\nsamples = 32\nvalue = [4, 1, 5, 6, 6, 1, 9]\nclass = Sci-Fi'),
#  Text(0.0025459327601453784, 0.6636363636363637, 'Watch_Time_Hours <= 339.715\ngini = 0.767\nsamples = 23\nvalue = [2, 0, 3, 5, 6, 0, 7]\nclass = Sci-Fi'),
#  Text(0.0023217625800067915, 0.6454545454545455, 'Age <= 20.5\ngini = 0.76\nsamples = 11\nvalue = [2, 0, 2, 2, 1, 0, 4]\nclass = Sci-Fi'),
#  Text(0.002161641022764944, 0.6272727272727273, 'Watch_Time_Hours <= 326.57\ngini = 0.656\nsamples = 8\nvalue = [1, 0, 1, 2, 0, 0, 4]\nclass = Sci-Fi'),
#  Text(0.002097592399868205, 0.6090909090909091, 'Age <= 17.0\ngini = 0.722\nsamples = 6\nvalue = [1, 0, 1, 2, 0, 0, 2]\nclass = Romance'),
#  Text(0.001969495154074727, 0.5909090909090909, 'Watch_Time_Hours <= 256.955\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 0, 0, 0, 1]\nclass = Horror'),
#  Text(0.0019054465311779878, 0.5727272727272728, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.002033543776971466, 0.5727272727272728, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.0022256896456616833, 0.5909090909090909, 'Watch_Time_Hours <= 280.135\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 1, 2, 0, 0, 1]\nclass = Romance'),
#  Text(0.002161641022764944, 0.5727272727272728, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.002289738268558422, 0.5727272727272728, 'Watch_Time_Hours <= 301.18\ngini = 0.667\nsamples = 3\nvalue = [0, 0, 1, 1, 0, 0, 1]\nclass = Action'),
#  Text(0.0022256896456616833, 0.5545454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.002353786891455161, 0.5545454545454546, 'Watch_Time_Hours <= 313.26\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 0, 1]\nclass = Romance'),
#  Text(0.002289738268558422, 0.5363636363636364, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.0024178355143519, 0.5363636363636364, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.0022256896456616833, 0.6090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]\nclass = Sci-Fi'),
#  Text(0.0024818841372486393, 0.6272727272727273, 'Age <= 21.5\ngini = 0.667\nsamples = 3\nvalue = [1, 0, 1, 0, 1, 0, 0]\nclass = Horror'),
#  Text(0.0024178355143519, 0.6090909090909091, 'Watch_Time_Hours <= 293.065\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 0, 1, 0, 0]\nclass = Horror'),
#  Text(0.002353786891455161, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Comedy'),
#  Text(0.0024818841372486393, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.0025459327601453784, 0.6090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.0027701029402839653, 0.6454545454545455, 'Watch_Time_Hours <= 345.895\ngini = 0.694\nsamples = 12\nvalue = [0, 0, 1, 3, 5, 0, 3]\nclass = Comedy'),
#  Text(0.002706054317387226, 0.6272727272727273, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0, 0]\nclass = Comedy'),
#  Text(0.0028341515631807044, 0.6272727272727273, 'Age <= 14.0\ngini = 0.72\nsamples = 10\nvalue = [0, 0, 1, 3, 3, 0, 3]\nclass = Romance'),
#  Text(0.0026740300059388566, 0.6090909090909091, 'Watch_Time_Hours <= 361.82\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 1, 0, 0, 0]\nclass = Action'),
#  Text(0.0026099813830421175, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.0027380786288355957, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.002994273120422552, 0.6090909090909091, 'Watch_Time_Hours <= 383.02\ngini = 0.656\nsamples = 8\nvalue = [0, 0, 0, 2, 3, 0, 3]\nclass = Comedy'),
#  Text(0.002866175874629074, 0.5909090909090909, 'Watch_Time_Hours <= 351.2\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 0, 2, 0, 1]\nclass = Comedy'),
#  Text(0.002802127251732335, 0.5727272727272728, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.002930224497525813, 0.5727272727272728, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0, 0]\nclass = Comedy'),
#  Text(0.0031223703662160303, 0.5909090909090909, 'Age <= 19.5\ngini = 0.64\nsamples = 5\nvalue = [0, 0, 0, 2, 1, 0, 2]\nclass = Romance'),
#  Text(0.0030583217433192912, 0.5727272727272728, 'Age <= 16.5\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 0, 1, 1, 0, 2]\nclass = Sci-Fi'),
#  Text(0.002930224497525813, 0.5545454545454546, 'Watch_Time_Hours <= 400.235\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 0, 1]\nclass = Romance'),
#  Text(0.002866175874629074, 0.5363636363636364, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.002994273120422552, 0.5363636363636364, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.0031864189891127694, 0.5545454545454546, 'Watch_Time_Hours <= 402.885\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 0, 1]\nclass = Comedy'),
#  Text(0.0031223703662160303, 0.5363636363636364, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Comedy'),
#  Text(0.0032504676120095085, 0.5363636363636364, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.0031864189891127694, 0.5727272727272728, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.003346540546354617, 0.6636363636363637, 'Watch_Time_Hours <= 407.33\ngini = 0.815\nsamples = 9\nvalue = [2, 1, 2, 1, 0, 1, 2]\nclass = Horror'),
#  Text(0.0031864189891127694, 0.6454545454545455, 'Age <= 17.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 0, 0, 1, 0]\nclass = Horror'),
#  Text(0.0031223703662160303, 0.6272727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.0032504676120095085, 0.6272727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.0035066621035964645, 0.6454545454545455, 'Watch_Time_Hours <= 416.17\ngini = 0.776\nsamples = 7\nvalue = [1, 1, 2, 1, 0, 0, 2]\nclass = Action'),
#  Text(0.0033785648578029868, 0.6272727272727273, 'Watch_Time_Hours <= 409.03\ngini = 0.72\nsamples = 5\nvalue = [0, 1, 2, 1, 0, 0, 1]\nclass = Action'),
#  Text(0.0033145162349062477, 0.6090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.0034426134806997254, 0.6090909090909091, 'Age <= 16.0\ngini = 0.75\nsamples = 4\nvalue = [0, 1, 1, 1, 0, 0, 1]\nclass = Documentary'),
#  Text(0.0033785648578029868, 0.5909090909090909, 'Watch_Time_Hours <= 411.395\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 1, 0, 0, 0, 1]\nclass = Documentary'),
#  Text(0.0033145162349062477, 0.5727272727272728, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.0034426134806997254, 0.5727272727272728, 'Watch_Time_Hours <= 414.665\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.0033785648578029868, 0.5545454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.0035066621035964645, 0.5545454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.0035066621035964645, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.0036347593493899428, 0.6272727272727273, 'Age <= 18.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 0, 0, 0, 1]\nclass = Horror'),
#  Text(0.0035707107264932036, 0.6090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.003698807972286682, 0.6090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.003074333899043476, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Comedy'),
#  Text(0.003138382521940215, 0.7363636363636363, 'Watch_Time_Hours <= 463.05\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.003074333899043476, 0.7181818181818181, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.003202431144836954, 0.7181818181818181, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.010981529420148082, 0.8090909090909091, 'Watch_Time_Hours <= 19.7\ngini = 0.854\nsamples = 517\nvalue = [99, 76, 69, 75, 70, 63, 65]\nclass = Horror'),
#  Text(0.003618747193665758, 0.7909090909090909, 'Age <= 19.5\ngini = 0.741\nsamples = 18\nvalue = [7, 1, 0, 5, 1, 2, 2]\nclass = Horror'),
#  Text(0.003554698570769019, 0.7727272727272727, 'Age <= 15.5\ngini = 0.688\nsamples = 16\nvalue = [7, 1, 0, 5, 1, 0, 2]\nclass = Horror'),
#  Text(0.003330528390630432, 0.7545454545454545, 'Country <= 6.5\ngini = 0.56\nsamples = 5\nvalue = [0, 0, 0, 3, 1, 0, 1]\nclass = Romance'),
#  Text(0.003266479767733693, 0.7363636363636363, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0, 0]\nclass = Romance'),
#  Text(0.0033945770135271713, 0.7363636363636363, 'Age <= 14.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 0, 1]\nclass = Comedy'),
#  Text(0.003330528390630432, 0.7181818181818181, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.0034586256364239104, 0.7181818181818181, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Comedy'),
#  Text(0.003778868750907606, 0.7545454545454545, 'Country <= 4.5\ngini = 0.545\nsamples = 11\nvalue = [7, 1, 0, 2, 0, 0, 1]\nclass = Horror'),
#  Text(0.0036507715051141277, 0.7363636363636363, 'Watch_Time_Hours <= 13.225\ngini = 0.72\nsamples = 5\nvalue = [2, 1, 0, 1, 0, 0, 1]\nclass = Horror'),
#  Text(0.0035867228822173886, 0.7181818181818181, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.003714820128010867, 0.7181818181818181, 'Age <= 17.5\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 0, 1, 0, 0, 1]\nclass = Documentary'),
#  Text(0.0036507715051141277, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.003778868750907606, 0.7, 'Watch_Time_Hours <= 17.595\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 0, 1]\nclass = Romance'),
#  Text(0.003714820128010867, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.003842917373804345, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.003906965996701084, 0.7363636363636363, 'Watch_Time_Hours <= 10.045\ngini = 0.278\nsamples = 6\nvalue = [5, 0, 0, 1, 0, 0, 0]\nclass = Horror'),
#  Text(0.003842917373804345, 0.7181818181818181, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.003971014619597823, 0.7181818181818181, 'gini = 0.0\nsamples = 5\nvalue = [5, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.0036827958165624973, 0.7727272727272727, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2, 0]\nclass = Drama'),
#  Text(0.018344311646630404, 0.7909090909090909, 'Watch_Time_Hours <= 457.225\ngini = 0.855\nsamples = 499\nvalue = [92.0, 75.0, 69.0, 70.0, 69.0, 61.0, 63.0]\nclass = Horror'),
#  Text(0.01508021914347346, 0.7727272727272727, 'Watch_Time_Hours <= 444.36\ngini = 0.855\nsamples = 486\nvalue = [88.0, 75.0, 65.0, 67.0, 67.0, 61.0, 63.0]\nclass = Horror'),
#  Text(0.008968350185988374, 0.7545454545454545, 'Age <= 13.5\ngini = 0.855\nsamples = 472\nvalue = [87.0, 69.0, 65.0, 63.0, 66.0, 60.0, 62.0]\nclass = Horror'),
#  Text(0.00469956770504823, 0.7363636363636363, 'Watch_Time_Hours <= 419.7\ngini = 0.82\nsamples = 47\nvalue = [14.0, 6.0, 5.0, 5.0, 5.0, 3.0, 9.0]\nclass = Horror'),
#  Text(0.004435367135599181, 0.7181818181818181, 'Country <= 1.5\ngini = 0.808\nsamples = 44\nvalue = [14, 6, 4, 5, 3, 3, 9]\nclass = Horror'),
#  Text(0.004099111865391301, 0.7, 'Watch_Time_Hours <= 316.66\ngini = 0.667\nsamples = 6\nvalue = [1, 0, 1, 0, 0, 1, 3]\nclass = Sci-Fi'),
#  Text(0.003971014619597823, 0.6818181818181818, 'Watch_Time_Hours <= 208.98\ngini = 0.375\nsamples = 4\nvalue = [1, 0, 0, 0, 0, 0, 3]\nclass = Sci-Fi'),
#  Text(0.003906965996701084, 0.6636363636363637, 'Watch_Time_Hours <= 158.53\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 0, 0, 0, 1]\nclass = Horror'),
#  Text(0.003842917373804345, 0.6454545454545455, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.003971014619597823, 0.6454545454545455, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.004035063242494562, 0.6636363636363637, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]\nclass = Sci-Fi'),
#  Text(0.004227209111184779, 0.6818181818181818, 'Watch_Time_Hours <= 358.325\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 0, 1, 0]\nclass = Action'),
#  Text(0.00416316048828804, 0.6636363636363637, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.004291257734081518, 0.6636363636363637, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.004771622405807061, 0.7, 'Watch_Time_Hours <= 22.8\ngini = 0.801\nsamples = 38\nvalue = [13, 6, 3, 5, 3, 2, 6]\nclass = Horror'),
#  Text(0.004707573782910322, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.0048356710287038, 0.6818181818181818, 'Watch_Time_Hours <= 78.38\ngini = 0.793\nsamples = 37\nvalue = [13, 6, 2, 5, 3, 2, 6]\nclass = Horror'),
#  Text(0.004419354979874997, 0.6636363636363637, 'Watch_Time_Hours <= 51.6\ngini = 0.531\nsamples = 8\nvalue = [5, 1, 0, 0, 0, 0, 2]\nclass = Horror'),
#  Text(0.0043553063569782575, 0.6454545454545455, 'Watch_Time_Hours <= 25.97\ngini = 0.625\nsamples = 4\nvalue = [1, 1, 0, 0, 0, 0, 2]\nclass = Sci-Fi'),
#  Text(0.004291257734081518, 0.6272727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.004419354979874997, 0.6272727272727273, 'Country <= 2.5\ngini = 0.667\nsamples = 3\nvalue = [1, 1, 0, 0, 0, 0, 1]\nclass = Horror'),
#  Text(0.0043553063569782575, 0.6090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.004483403602771736, 0.6090909090909091, 'Watch_Time_Hours <= 35.965\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.004419354979874997, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.004547452225668475, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.004483403602771736, 0.6454545454545455, 'gini = 0.0\nsamples = 4\nvalue = [4, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.005251987077532605, 0.6636363636363637, 'Watch_Time_Hours <= 156.33\ngini = 0.825\nsamples = 29\nvalue = [8, 5, 2, 5, 3, 2, 4]\nclass = Horror'),
#  Text(0.004931743963048909, 0.6454545454545455, 'Watch_Time_Hours <= 116.885\ngini = 0.781\nsamples = 8\nvalue = [0, 1, 2, 2, 1, 2, 0]\nclass = Action'),
#  Text(0.004803646717255431, 0.6272727272727273, 'Watch_Time_Hours <= 101.705\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 2, 0, 0, 1, 0]\nclass = Action'),
#  Text(0.004739598094358692, 0.6090909090909091, 'Watch_Time_Hours <= 89.06\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 0, 1, 0]\nclass = Documentary'),
#  Text(0.004675549471461953, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.004803646717255431, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.00486769534015217, 0.6090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.005059841208842388, 0.6272727272727273, 'Country <= 4.5\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 0, 2, 1, 1, 0]\nclass = Romance'),
#  Text(0.0049957925859456485, 0.6090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.005123889831739127, 0.6090909090909091, 'Watch_Time_Hours <= 143.76\ngini = 0.667\nsamples = 3\nvalue = [0, 0, 0, 1, 1, 1, 0]\nclass = Romance'),
#  Text(0.005059841208842388, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.005187938454635866, 0.5909090909090909, 'Country <= 8.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0, 0]\nclass = Romance'),
#  Text(0.005123889831739127, 0.5727272727272728, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Comedy'),
#  Text(0.005251987077532605, 0.5727272727272728, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.0055722301920163005, 0.6454545454545455, 'Watch_Time_Hours <= 198.705\ngini = 0.753\nsamples = 21\nvalue = [8, 4, 0, 3, 2, 0, 4]\nclass = Horror'),
#  Text(0.005444132946222822, 0.6272727272727273, 'Watch_Time_Hours <= 182.215\ngini = 0.48\nsamples = 5\nvalue = [3, 2, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.005380084323326083, 0.6090909090909091, 'Watch_Time_Hours <= 166.235\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.005316035700429344, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.005444132946222822, 0.5909090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.005508181569119561, 0.6090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.005700327437809779, 0.6272727272727273, 'Watch_Time_Hours <= 226.81\ngini = 0.773\nsamples = 16\nvalue = [5, 2, 0, 3, 2, 0, 4]\nclass = Horror'),
#  Text(0.00563627881491304, 0.6090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 0, 2]\nclass = Sci-Fi'),
#  Text(0.005764376060706517, 0.6090909090909091, 'Watch_Time_Hours <= 237.895\ngini = 0.765\nsamples = 14\nvalue = [5, 2, 0, 3, 2, 0, 2]\nclass = Horror'),
#  Text(0.005700327437809779, 0.5909090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0, 0]\nclass = Romance'),
#  Text(0.005828424683603256, 0.5909090909090909, 'Watch_Time_Hours <= 243.87\ngini = 0.736\nsamples = 12\nvalue = [5, 2, 0, 1, 2, 0, 2]\nclass = Horror'),
#  Text(0.005764376060706517, 0.5727272727272728, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Comedy'),
#  Text(0.005892473306499995, 0.5727272727272728, 'Watch_Time_Hours <= 399.255\ngini = 0.711\nsamples = 11\nvalue = [5, 2, 0, 1, 1, 0, 2]\nclass = Horror'),
#  Text(0.005828424683603256, 0.5545454545454546, 'Country <= 6.0\ngini = 0.68\nsamples = 10\nvalue = [5, 2, 0, 1, 1, 0, 1]\nclass = Horror'),
#  Text(0.005668303126361409, 0.5363636363636364, 'Watch_Time_Hours <= 339.955\ngini = 0.48\nsamples = 5\nvalue = [3, 2, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.00560425450346467, 0.5181818181818182, 'Country <= 2.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.0055402058805679305, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.005668303126361409, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.005732351749258148, 0.5181818181818182, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.005988546240845104, 0.5363636363636364, 'Watch_Time_Hours <= 359.155\ngini = 0.72\nsamples = 5\nvalue = [2, 0, 0, 1, 1, 0, 1]\nclass = Horror'),
#  Text(0.005860448995051626, 0.5181818181818182, 'Watch_Time_Hours <= 299.3\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 0, 0, 0, 1]\nclass = Horror'),
#  Text(0.005796400372154887, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.005924497617948365, 0.5, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.0061166434866385825, 0.5181818181818182, 'Watch_Time_Hours <= 377.18\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0, 0]\nclass = Romance'),
#  Text(0.006052594863741843, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.006180692109535322, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Comedy'),
#  Text(0.005956521929396734, 0.5545454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.0049637682744972786, 0.7181818181818181, 'Country <= 5.0\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 0, 2, 0, 0]\nclass = Comedy'),
#  Text(0.0048997196516005394, 0.7, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0, 0]\nclass = Comedy'),
#  Text(0.005027816897394018, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.013237132666928518, 0.7363636363636363, 'Age <= 14.5\ngini = 0.856\nsamples = 425\nvalue = [73.0, 63.0, 60.0, 58.0, 61.0, 57.0, 53.0]\nclass = Horror'),
#  Text(0.007501694956780565, 0.7181818181818181, 'Country <= 7.5\ngini = 0.794\nsamples = 47\nvalue = [3.0, 16.0, 4.0, 5.0, 8.0, 9.0, 2.0]\nclass = Documentary'),
#  Text(0.007237494387331516, 0.7, 'Watch_Time_Hours <= 41.385\ngini = 0.77\nsamples = 41\nvalue = [3.0, 16.0, 4.0, 2.0, 7.0, 7.0, 2.0]\nclass = Documentary'),
#  Text(0.007173445764434777, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.0073015430102282555, 0.6818181818181818, 'Country <= 1.5\ngini = 0.762\nsamples = 40\nvalue = [3, 16, 3, 2, 7, 7, 2]\nclass = Documentary'),
#  Text(0.007125409297262223, 0.6636363636363637, 'Watch_Time_Hours <= 75.865\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 0, 0, 2, 0]\nclass = Drama'),
#  Text(0.007061360674365484, 0.6454545454545455, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.007189457920158962, 0.6454545454545455, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2, 0]\nclass = Drama'),
#  Text(0.007477676723194287, 0.6636363636363637, 'Watch_Time_Hours <= 370.425\ngini = 0.763\nsamples = 37\nvalue = [3, 15, 3, 2, 7, 5, 2]\nclass = Documentary'),
#  Text(0.00731755516595244, 0.6454545454545455, 'Watch_Time_Hours <= 364.88\ngini = 0.755\nsamples = 31\nvalue = [3, 13, 3, 2, 6, 2, 2]\nclass = Documentary'),
#  Text(0.007253506543055701, 0.6272727272727273, 'Watch_Time_Hours <= 335.965\ngini = 0.744\nsamples = 30\nvalue = [2, 13, 3, 2, 6, 2, 2]\nclass = Documentary'),
#  Text(0.007189457920158962, 0.6090909090909091, 'Country <= 6.5\ngini = 0.779\nsamples = 27\nvalue = [2, 10, 3, 2, 6, 2, 2]\nclass = Documentary'),
#  Text(0.006917251272847821, 0.5909090909090909, 'Watch_Time_Hours <= 263.49\ngini = 0.764\nsamples = 22\nvalue = [2, 9, 1, 2, 4, 2, 2]\nclass = Documentary'),
#  Text(0.006693081092709234, 0.5727272727272728, 'Country <= 5.5\ngini = 0.75\nsamples = 16\nvalue = [2, 7, 1, 2, 1, 1, 2]\nclass = Documentary'),
#  Text(0.006564983846915756, 0.5545454545454546, 'Watch_Time_Hours <= 236.525\ngini = 0.611\nsamples = 12\nvalue = [1, 7, 1, 1, 0, 0, 2]\nclass = Documentary'),
#  Text(0.006500935224019017, 0.5363636363636364, 'Country <= 3.5\ngini = 0.562\nsamples = 11\nvalue = [1, 7, 1, 1, 0, 0, 1]\nclass = Documentary'),
#  Text(0.006436886601122278, 0.5181818181818182, 'Watch_Time_Hours <= 120.965\ngini = 0.778\nsamples = 6\nvalue = [1, 2, 1, 1, 0, 0, 1]\nclass = Documentary'),
#  Text(0.0063087893553288, 0.5, 'Watch_Time_Hours <= 53.005\ngini = 0.625\nsamples = 4\nvalue = [1, 2, 1, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.006244740732432061, 0.4818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.006372837978225539, 0.4818181818181818, 'Watch_Time_Hours <= 56.28\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.0063087893553288, 0.4636363636363636, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.006436886601122278, 0.4636363636363636, 'Watch_Time_Hours <= 70.14\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 1, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.006372837978225539, 0.44545454545454544, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.006500935224019017, 0.44545454545454544, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.006564983846915756, 0.5, 'Watch_Time_Hours <= 176.315\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 0, 1]\nclass = Romance'),
#  Text(0.006500935224019017, 0.4818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.006629032469812495, 0.4818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.006564983846915756, 0.5181818181818182, 'gini = 0.0\nsamples = 5\nvalue = [0, 5, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.006629032469812495, 0.5363636363636364, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.006821178338502713, 0.5545454545454546, 'Watch_Time_Hours <= 67.995\ngini = 0.75\nsamples = 4\nvalue = [1, 0, 0, 1, 1, 1, 0]\nclass = Horror'),
#  Text(0.0067571297156059735, 0.5363636363636364, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.006885226961399451, 0.5363636363636364, 'Watch_Time_Hours <= 129.655\ngini = 0.667\nsamples = 3\nvalue = [1, 0, 0, 1, 1, 0, 0]\nclass = Horror'),
#  Text(0.006821178338502713, 0.5181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Comedy'),
#  Text(0.00694927558429619, 0.5181818181818182, 'Watch_Time_Hours <= 225.885\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1, 0, 0, 0]\nclass = Horror'),
#  Text(0.006885226961399451, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.007013324207192929, 0.5, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.007141421452986407, 0.5727272727272728, 'Watch_Time_Hours <= 285.665\ngini = 0.611\nsamples = 6\nvalue = [0, 2, 0, 0, 3, 1, 0]\nclass = Comedy'),
#  Text(0.007077372830089668, 0.5545454545454546, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 2, 0, 0]\nclass = Comedy'),
#  Text(0.007205470075883146, 0.5545454545454546, 'Country <= 4.5\ngini = 0.625\nsamples = 4\nvalue = [0, 2, 0, 0, 1, 1, 0]\nclass = Documentary'),
#  Text(0.007141421452986407, 0.5363636363636364, 'Watch_Time_Hours <= 315.66\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 1, 1, 0]\nclass = Comedy'),
#  Text(0.007077372830089668, 0.5181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.007205470075883146, 0.5181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Comedy'),
#  Text(0.0072695186987798855, 0.5363636363636364, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.007461664567470103, 0.5909090909090909, 'Watch_Time_Hours <= 249.275\ngini = 0.64\nsamples = 5\nvalue = [0, 1, 2, 0, 2, 0, 0]\nclass = Action'),
#  Text(0.007397615944573364, 0.5727272727272728, 'Watch_Time_Hours <= 115.58\ngini = 0.5\nsamples = 4\nvalue = [0, 0, 2, 0, 2, 0, 0]\nclass = Action'),
#  Text(0.007333567321676625, 0.5545454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Comedy'),
#  Text(0.007461664567470103, 0.5545454545454546, 'Watch_Time_Hours <= 221.115\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 2, 0, 1, 0, 0]\nclass = Action'),
#  Text(0.007397615944573364, 0.5363636363636364, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.007525713190366842, 0.5363636363636364, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Comedy'),
#  Text(0.007525713190366842, 0.5727272727272728, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.00731755516595244, 0.6090909090909091, 'gini = 0.0\nsamples = 3\nvalue = [0, 3, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.007381603788849179, 0.6272727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.007637798280436136, 0.6454545454545455, 'Watch_Time_Hours <= 407.515\ngini = 0.611\nsamples = 6\nvalue = [0, 2, 0, 0, 1, 3, 0]\nclass = Drama'),
#  Text(0.007509701034642657, 0.6272727272727273, 'Country <= 3.5\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 0, 1, 2, 0]\nclass = Drama'),
#  Text(0.007445652411745918, 0.6090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Comedy'),
#  Text(0.0075737496575393965, 0.6090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2, 0]\nclass = Drama'),
#  Text(0.007765895526229614, 0.6272727272727273, 'Watch_Time_Hours <= 421.355\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 0, 0, 0, 1, 0]\nclass = Documentary'),
#  Text(0.007701846903332875, 0.6090909090909091, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.007829944149126352, 0.6090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.007765895526229614, 0.7, 'Watch_Time_Hours <= 87.55\ngini = 0.611\nsamples = 6\nvalue = [0, 0, 0, 3, 1, 2, 0]\nclass = Romance'),
#  Text(0.007701846903332875, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.007829944149126352, 0.6818181818181818, 'Watch_Time_Hours <= 179.565\ngini = 0.64\nsamples = 5\nvalue = [0, 0, 0, 2, 1, 2, 0]\nclass = Romance'),
#  Text(0.007765895526229614, 0.6636363636363637, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.007893992772023092, 0.6636363636363637, 'Country <= 8.5\ngini = 0.625\nsamples = 4\nvalue = [0, 0, 0, 2, 1, 1, 0]\nclass = Romance'),
#  Text(0.007829944149126352, 0.6454545454545455, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.00795804139491983, 0.6454545454545455, 'Watch_Time_Hours <= 288.405\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 1, 0, 0]\nclass = Romance'),
#  Text(0.007893992772023092, 0.6272727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.00802209001781657, 0.6272727272727273, 'Watch_Time_Hours <= 370.61\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 1, 0, 0]\nclass = Romance'),
#  Text(0.00795804139491983, 0.6090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Comedy'),
#  Text(0.008086138640713308, 0.6090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.018972570377076472, 0.7181818181818181, 'Watch_Time_Hours <= 415.08\ngini = 0.855\nsamples = 378\nvalue = [70, 47, 56, 53, 53, 48, 51]\nclass = Horror'),
#  Text(0.017361514570713422, 0.7, 'Watch_Time_Hours <= 383.195\ngini = 0.854\nsamples = 350\nvalue = [65.0, 44.0, 54.0, 49.0, 50.0, 46.0, 42.0]\nclass = Horror'),
#  Text(0.015180193080059332, 0.6818181818181818, 'Country <= 8.5\ngini = 0.855\nsamples = 324\nvalue = [57, 43, 51, 46, 47, 39, 41]\nclass = Horror'),
#  Text(0.0119223888437199, 0.6636363636363637, 'Age <= 19.5\ngini = 0.854\nsamples = 285\nvalue = [54.0, 35.0, 41.0, 43.0, 40.0, 35.0, 37.0]\nclass = Horror'),
#  Text(0.008765330034188794, 0.6454545454545455, 'Watch_Time_Hours <= 52.99\ngini = 0.85\nsamples = 183\nvalue = [37.0, 20.0, 28.0, 24.0, 26.0, 18.0, 30.0]\nclass = Horror'),
#  Text(0.008278284509403527, 0.6272727272727273, 'Age <= 18.0\ngini = 0.755\nsamples = 14\nvalue = [1, 2, 0, 4, 1, 1, 5]\nclass = Sci-Fi'),
#  Text(0.008214235886506787, 0.6090909090909091, 'Watch_Time_Hours <= 31.215\ngini = 0.777\nsamples = 11\nvalue = [1, 2, 0, 4, 1, 1, 2]\nclass = Romance'),
#  Text(0.008086138640713308, 0.5909090909090909, 'Watch_Time_Hours <= 29.25\ngini = 0.625\nsamples = 4\nvalue = [0, 1, 0, 0, 1, 0, 2]\nclass = Sci-Fi'),
#  Text(0.00802209001781657, 0.5727272727272728, 'Watch_Time_Hours <= 23.065\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 0, 0, 0, 0, 2]\nclass = Sci-Fi'),
#  Text(0.00795804139491983, 0.5545454545454546, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.008086138640713308, 0.5545454545454546, 'Watch_Time_Hours <= 26.31\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 0, 0, 1]\nclass = Documentary'),
#  Text(0.00802209001781657, 0.5363636363636364, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.008150187263610048, 0.5363636363636364, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.008150187263610048, 0.5727272727272728, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Comedy'),
#  Text(0.008342333132300265, 0.5909090909090909, 'Watch_Time_Hours <= 35.075\ngini = 0.612\nsamples = 7\nvalue = [1, 1, 0, 4, 0, 1, 0]\nclass = Romance'),
#  Text(0.008278284509403527, 0.5727272727272728, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 3, 0, 0, 0]\nclass = Romance'),
#  Text(0.008406381755197005, 0.5727272727272728, 'Watch_Time_Hours <= 35.88\ngini = 0.75\nsamples = 4\nvalue = [1, 1, 0, 1, 0, 1, 0]\nclass = Horror'),
#  Text(0.008342333132300265, 0.5545454545454546, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.008470430378093743, 0.5545454545454546, 'Watch_Time_Hours <= 41.58\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 0, 1, 0, 1, 0]\nclass = Documentary'),
#  Text(0.008406381755197005, 0.5363636363636364, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.008534479000990483, 0.5363636363636364, 'Age <= 15.5\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1, 0]\nclass = Romance'),
#  Text(0.008470430378093743, 0.5181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.008598527623887221, 0.5181818181818182, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.008342333132300265, 0.6090909090909091, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 0, 0, 0, 0, 3]\nclass = Sci-Fi'),
#  Text(0.009252375558974062, 0.6272727272727273, 'Watch_Time_Hours <= 78.36\ngini = 0.848\nsamples = 169\nvalue = [36.0, 18.0, 28.0, 20.0, 25.0, 17.0, 25.0]\nclass = Horror'),
#  Text(0.008662576246783961, 0.6090909090909091, 'Age <= 15.5\ngini = 0.673\nsamples = 14\nvalue = [2, 1, 7, 3, 1, 0, 0]\nclass = Action'),
#  Text(0.008598527623887221, 0.5909090909090909, 'gini = 0.0\nsamples = 4\nvalue = [0, 0, 4, 0, 0, 0, 0]\nclass = Action'),
# ...
#  Text(0.021896622952822672, 0.6636363636363637, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.022024720198616152, 0.6636363636363637, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.021960671575719414, 0.7181818181818181, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.022983948402468094, 0.8272727272727273, 'Country <= 0.5\ngini = 0.804\nsamples = 60\nvalue = [20, 9, 4, 8, 3, 10, 6]\nclass = Horror'),
#  Text(0.022064750587926615, 0.8090909090909091, 'Watch_Time_Hours <= 94.39\ngini = 0.408\nsamples = 7\nvalue = [5, 0, 0, 0, 0, 2, 0]\nclass = Horror'),
#  Text(0.022000701965029873, 0.7909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.022128799210823353, 0.7909090909090909, 'Watch_Time_Hours <= 345.0\ngini = 0.278\nsamples = 6\nvalue = [5, 0, 0, 0, 0, 1, 0]\nclass = Horror'),
#  Text(0.022064750587926615, 0.7727272727272727, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.02219284783372009, 0.7727272727272727, 'Watch_Time_Hours <= 410.225\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 0, 0, 1, 0]\nclass = Horror'),
#  Text(0.022128799210823353, 0.7545454545454545, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.02225689645661683, 0.7545454545454545, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.023903146217009577, 0.8090909090909091, 'Watch_Time_Hours <= 463.43\ngini = 0.824\nsamples = 53\nvalue = [15, 9, 4, 8, 3, 8, 6]\nclass = Horror'),
#  Text(0.023539870434017136, 0.7909090909090909, 'Watch_Time_Hours <= 365.225\ngini = 0.814\nsamples = 51\nvalue = [15, 9, 3, 8, 2, 8, 6]\nclass = Horror'),
#  Text(0.023005464736722468, 0.7727272727272727, 'Watch_Time_Hours <= 306.045\ngini = 0.827\nsamples = 39\nvalue = [9, 8, 2, 7, 2, 5, 6]\nclass = Horror'),
#  Text(0.02238499370241031, 0.7545454545454545, 'Country <= 8.5\ngini = 0.811\nsamples = 28\nvalue = [9, 3, 2, 5, 2, 4, 3]\nclass = Horror'),
#  Text(0.02232094507951357, 0.7363636363636363, 'Country <= 1.5\ngini = 0.804\nsamples = 27\nvalue = [9, 3, 2, 5, 2, 4, 2]\nclass = Horror'),
#  Text(0.02208876882151289, 0.7181818181818181, 'Watch_Time_Hours <= 180.745\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 1, 1]\nclass = Drama'),
#  Text(0.022024720198616152, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.02215281744440963, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.022553121337514248, 0.7181818181818181, 'Watch_Time_Hours <= 86.505\ngini = 0.787\nsamples = 25\nvalue = [9, 3, 2, 5, 2, 3, 1]\nclass = Horror'),
#  Text(0.02228091469020311, 0.7, 'Country <= 6.5\ngini = 0.667\nsamples = 6\nvalue = [3, 1, 0, 0, 1, 0, 1]\nclass = Horror'),
#  Text(0.02221686606730637, 0.6818181818181818, 'Watch_Time_Hours <= 67.645\ngini = 0.56\nsamples = 5\nvalue = [3, 1, 0, 0, 1, 0, 0]\nclass = Horror'),
#  Text(0.02215281744440963, 0.6636363636363637, 'Country <= 4.5\ngini = 0.667\nsamples = 3\nvalue = [1, 1, 0, 0, 1, 0, 0]\nclass = Horror'),
#  Text(0.02208876882151289, 0.6454545454545455, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Comedy'),
#  Text(0.02221686606730637, 0.6454545454545455, 'Watch_Time_Hours <= 41.395\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.02215281744440963, 0.6272727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.02228091469020311, 0.6272727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.02228091469020311, 0.6636363636363637, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.022344963313099847, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.02282532798482539, 0.7, 'Country <= 3.0\ngini = 0.781\nsamples = 19\nvalue = [6, 2, 2, 5, 1, 3, 0]\nclass = Horror'),
#  Text(0.022473060558893327, 0.6818181818181818, 'Watch_Time_Hours <= 105.04\ngini = 0.444\nsamples = 3\nvalue = [1, 0, 0, 2, 0, 0, 0]\nclass = Romance'),
#  Text(0.022409011935996585, 0.6636363636363637, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.022537109181790065, 0.6636363636363637, 'Watch_Time_Hours <= 206.255\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1, 0, 0, 0]\nclass = Horror'),
#  Text(0.022473060558893327, 0.6454545454545455, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.022601157804686803, 0.6454545454545455, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.023177595410757455, 0.6818181818181818, 'Country <= 5.5\ngini = 0.797\nsamples = 16\nvalue = [5, 2, 2, 3, 1, 3, 0]\nclass = Horror'),
#  Text(0.02285735229627376, 0.6636363636363637, 'Watch_Time_Hours <= 100.93\ngini = 0.64\nsamples = 5\nvalue = [2, 2, 0, 0, 0, 1, 0]\nclass = Horror'),
#  Text(0.02272925505048028, 0.6454545454545455, 'Watch_Time_Hours <= 88.72\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 0, 0, 1, 0]\nclass = Horror'),
#  Text(0.02266520642758354, 0.6272727272727273, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.02279330367337702, 0.6272727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.022985449542067236, 0.6454545454545455, 'Country <= 4.5\ngini = 0.444\nsamples = 3\nvalue = [1, 2, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.022921400919170498, 0.6272727272727273, 'Watch_Time_Hours <= 154.85\ngini = 0.5\nsamples = 2\nvalue = [1, 1, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.02285735229627376, 0.6090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.022985449542067236, 0.6090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.023049498164963978, 0.6272727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.02349783852524115, 0.6636363636363637, 'Watch_Time_Hours <= 259.02\ngini = 0.777\nsamples = 11\nvalue = [3, 0, 2, 3, 1, 2, 0]\nclass = Horror'),
#  Text(0.023241644033654193, 0.6454545454545455, 'Watch_Time_Hours <= 105.685\ngini = 0.722\nsamples = 6\nvalue = [0, 0, 2, 2, 1, 1, 0]\nclass = Action'),
#  Text(0.023177595410757455, 0.6272727272727273, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Comedy'),
#  Text(0.023305692656550935, 0.6272727272727273, 'Country <= 7.5\ngini = 0.64\nsamples = 5\nvalue = [0, 0, 2, 2, 0, 1, 0]\nclass = Action'),
#  Text(0.023177595410757455, 0.6090909090909091, 'Watch_Time_Hours <= 115.99\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 1, 2, 0, 0, 0]\nclass = Romance'),
#  Text(0.023113546787860716, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.023241644033654193, 0.5909090909090909, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 2, 0, 0, 0]\nclass = Romance'),
#  Text(0.02343378990234441, 0.6090909090909091, 'Watch_Time_Hours <= 203.41\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 0, 1, 0]\nclass = Action'),
#  Text(0.023369741279447673, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.02349783852524115, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.023754033016828106, 0.6454545454545455, 'Watch_Time_Hours <= 297.525\ngini = 0.56\nsamples = 5\nvalue = [3, 0, 0, 1, 0, 1, 0]\nclass = Horror'),
#  Text(0.02362593577103463, 0.6272727272727273, 'Watch_Time_Hours <= 278.815\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 1, 0, 0, 0]\nclass = Horror'),
#  Text(0.02356188714813789, 0.6090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.023689984393931367, 0.6090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.023882130262621586, 0.6272727272727273, 'Watch_Time_Hours <= 300.13\ngini = 0.444\nsamples = 3\nvalue = [2, 0, 0, 0, 0, 1, 0]\nclass = Horror'),
#  Text(0.023818081639724847, 0.6090909090909091, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.023946178885518324, 0.6090909090909091, 'Watch_Time_Hours <= 301.79\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 0, 0, 1, 0]\nclass = Horror'),
#  Text(0.023882130262621586, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.024010227508415062, 0.5909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.022449042325307048, 0.7363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.02362593577103463, 0.7545454545454545, 'Watch_Time_Hours <= 355.235\ngini = 0.678\nsamples = 11\nvalue = [0, 5, 0, 2, 0, 1, 3]\nclass = Documentary'),
#  Text(0.02349783852524115, 0.7363636363636363, 'Country <= 1.5\ngini = 0.531\nsamples = 8\nvalue = [0, 5, 0, 0, 0, 1, 2]\nclass = Documentary'),
#  Text(0.02343378990234441, 0.7181818181818181, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.02356188714813789, 0.7181818181818181, 'Country <= 5.0\ngini = 0.449\nsamples = 7\nvalue = [0, 5, 0, 0, 0, 1, 1]\nclass = Documentary'),
#  Text(0.02349783852524115, 0.7, 'gini = 0.0\nsamples = 4\nvalue = [0, 4, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.02362593577103463, 0.7, 'Watch_Time_Hours <= 312.84\ngini = 0.667\nsamples = 3\nvalue = [0, 1, 0, 0, 0, 1, 1]\nclass = Documentary'),
#  Text(0.02356188714813789, 0.6818181818181818, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.023689984393931367, 0.6818181818181818, 'Watch_Time_Hours <= 316.065\ngini = 0.5\nsamples = 2\nvalue = [0, 1, 0, 0, 0, 1, 0]\nclass = Documentary'),
#  Text(0.02362593577103463, 0.6636363636363637, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.023754033016828106, 0.6636363636363637, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.023754033016828106, 0.7363636363636363, 'Watch_Time_Hours <= 359.6\ngini = 0.444\nsamples = 3\nvalue = [0, 0, 0, 2, 0, 0, 1]\nclass = Romance'),
#  Text(0.023689984393931367, 0.7181818181818181, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.023818081639724847, 0.7181818181818181, 'Country <= 4.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 0, 1]\nclass = Romance'),
#  Text(0.023754033016828106, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.023882130262621586, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 0, 1]\nclass = Sci-Fi'),
#  Text(0.024074276131311804, 0.7727272727272727, 'Watch_Time_Hours <= 442.635\ngini = 0.667\nsamples = 12\nvalue = [6, 1, 1, 1, 0, 3, 0]\nclass = Horror'),
#  Text(0.023946178885518324, 0.7545454545454545, 'Watch_Time_Hours <= 381.12\ngini = 0.688\nsamples = 8\nvalue = [3, 0, 1, 1, 0, 3, 0]\nclass = Horror'),
#  Text(0.023882130262621586, 0.7363636363636363, 'gini = 0.0\nsamples = 2\nvalue = [2, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.024010227508415062, 0.7363636363636363, 'Watch_Time_Hours <= 387.475\ngini = 0.667\nsamples = 6\nvalue = [1, 0, 1, 1, 0, 3, 0]\nclass = Drama'),
#  Text(0.023946178885518324, 0.7181818181818181, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.024074276131311804, 0.7181818181818181, 'Country <= 8.0\ngini = 0.56\nsamples = 5\nvalue = [1, 0, 0, 1, 0, 3, 0]\nclass = Drama'),
#  Text(0.024010227508415062, 0.7, 'Country <= 4.5\ngini = 0.375\nsamples = 4\nvalue = [0, 0, 0, 1, 0, 3, 0]\nclass = Drama'),
#  Text(0.023946178885518324, 0.6818181818181818, 'Country <= 3.0\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 0, 1, 0, 1, 0]\nclass = Romance'),
#  Text(0.023882130262621586, 0.6636363636363637, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.024010227508415062, 0.6636363636363637, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.024074276131311804, 0.6818181818181818, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 0, 0, 0, 2, 0]\nclass = Drama'),
#  Text(0.024138324754208542, 0.7, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.02420237337710528, 0.7545454545454545, 'Country <= 7.5\ngini = 0.375\nsamples = 4\nvalue = [3, 1, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.024138324754208542, 0.7363636363636363, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.02426642200000202, 0.7363636363636363, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0, 0, 0, 0, 0]\nclass = Documentary'),
#  Text(0.02426642200000202, 0.7909090909090909, 'Watch_Time_Hours <= 466.59\ngini = 0.5\nsamples = 2\nvalue = [0, 0, 1, 0, 1, 0, 0]\nclass = Action'),
#  Text(0.02420237337710528, 0.7727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 1, 0, 0]\nclass = Comedy'),
#  Text(0.02433047062289876, 0.7727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.08175355325085207, 0.8454545454545455, 'Watch_Time_Hours <= 467.935\ngini = 0.857\nsamples = 2460\nvalue = [363.0, 338.0, 345.0, 362.0, 390.0, 350.0, 312.0]\nclass = Comedy'),
#  Text(0.05260546148268763, 0.8272727272727273, 'Watch_Time_Hours <= 9.785\ngini = 0.857\nsamples = 2448\nvalue = [363.0, 336.0, 340.0, 360.0, 387.0, 350.0, 312.0]\nclass = Comedy'),
#  Text(0.024586665114485717, 0.8090909090909091, 'Country <= 8.0\ngini = 0.656\nsamples = 8\nvalue = [4, 0, 2, 1, 0, 1, 0]\nclass = Horror'),
#  Text(0.024522616491588975, 0.7909090909090909, 'Age <= 63.0\ngini = 0.571\nsamples = 7\nvalue = [4, 0, 2, 0, 0, 1, 0]\nclass = Horror'),
#  Text(0.024458567868692237, 0.7727272727272727, 'Watch_Time_Hours <= 7.675\ngini = 0.5\nsamples = 6\nvalue = [4, 0, 1, 0, 0, 1, 0]\nclass = Horror'),
#  Text(0.0243945192457955, 0.7545454545454545, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.024522616491588975, 0.7545454545454545, 'Country <= 5.0\ngini = 0.32\nsamples = 5\nvalue = [4, 0, 0, 0, 0, 1, 0]\nclass = Horror'),
#  Text(0.024458567868692237, 0.7363636363636363, 'gini = 0.0\nsamples = 3\nvalue = [3, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.024586665114485717, 0.7363636363636363, 'Age <= 42.5\ngini = 0.5\nsamples = 2\nvalue = [1, 0, 0, 0, 0, 1, 0]\nclass = Horror'),
#  Text(0.024522616491588975, 0.7181818181818181, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 0, 0, 1, 0]\nclass = Drama'),
#  Text(0.024650713737382455, 0.7181818181818181, 'gini = 0.0\nsamples = 1\nvalue = [1, 0, 0, 0, 0, 0, 0]\nclass = Horror'),
#  Text(0.024586665114485717, 0.7727272727272727, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1, 0, 0, 0, 0]\nclass = Action'),
#  Text(0.024650713737382455, 0.7909090909090909, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 0, 1, 0, 0, 0]\nclass = Romance'),
#  Text(0.08062425785088956, 0.8090909090909091, 'Watch_Time_Hours <= 358.53\ngini = 0.857\nsamples = 2440\nvalue = [359, 336, 338, 359, 387, 349, 312]\nclass = Comedy'),
#  Text(0.058963419922438004, 0.7909090909090909, 'Age <= 66.5\ngini = 0.857\nsamples = 1817\nvalue = [256.0, 238.0, 265.0, 259.0, 296.0, 259.0, 244.0]\nclass = Comedy'),
#  Text(0.031119939865406565, 0.7727272727272727, 'Watch_Time_Hours <= 16.445\ngini = 0.857\nsamples = 1787\nvalue = [256, 236, 259, 252, 286, 256, 242]\nclass = Comedy'),
#  Text(0.025259175654901475, 0.7545454545454545, 'Age <= 51.5\ngini = 0.803\nsamples = 33\nvalue = [5, 1, 3, 5, 11, 5, 3]\nclass = Comedy'),
#  Text(0.02497095685186615, 0.7363636363636363, 'Watch_Time_Hours <= 15.38\ngini = 0.784\nsamples = 18\nvalue = [0, 0, 2, 4, 5, 4, 3]\nclass = Comedy'),
#  Text(0.02477881098317593, 0.7181818181818181, 'Age <= 29.5\ngini = 0.781\nsamples = 13\nvalue = [0, 0, 2, 2, 2, 4, 3]\nclass = Drama'),
#  ...]
